# %% [markdown]
# # Домашнее задание к лекции "Поиск выбросов и генерация новых признаков" обновленное
# Задачи:
#
# Взять датасет
#
# Провести EDA с упором на пропущенные значения и выбросы
#
# Обучить простую модель несколько раз (см. ниже) и сравнить качество.
#
# При обучении модели постепенно фильтровать выбросы и заполнять пропуски. При фильтрации выбросов и заполнении пропусков при необходимости обосновывать выбранные методы.
#
# Сгенерировать не менее новых 5 признаков (генерация с помощью PolynomialFeatures считать как один признак) и обучить модель после каждого добавления нового признака для контроля качества.
#
# Построить изменения качества график качества модели на каждом шаге (после обработки каждого признака и после каждого добавления нового признака)
#
# Используйте столбцы [‘full_sq’, ‘life_sq’, ‘floor’, ‘max_floor’, ‘material’, ‘build_year’, ‘num_room’, ‘kitch_sq’, ‘state’, ‘area_m’, ‘raion_popul’, ‘green_zone_part’, ‘indust_part’, ‘preschool_education_centers_raion’, ‘school_education_centers_raion’, ‘hospital_beds_raion’, ‘healthcare_centers_raion’, ‘sport_objects_raion’, ‘additional_education_raion’, ‘shopping_centers_raion’, ‘office_raion’, ‘ID_metro’, ‘metro_min_walk’, ‘kindergarten_km’, ‘school_km’, ‘park_km’, ‘green_zone_km’, ‘industrial_km’, ‘water_km’, ‘mkad_km’, ‘ttk_km’, ‘sadovoe_km’, ‘bulvar_ring_km’, ‘kremlin_km’, ‘ts_km’, ‘big_market_km’,‘market_shop_km’, ‘fitness_km’, ‘university_km’, ‘workplaces_km’, ‘shopping_centers_km’, ‘office_km’, ‘additional_education_raion’, ‘preschool_km’, ‘price_doc’

# %%
# %matplotlib inline
import numpy as np
from sklearn.covariance import EllipticEnvelope
from sklearn.svm import OneClassSVM
import matplotlib.pyplot as plt
import matplotlib.font_manager
from sklearn.datasets import load_wine
from sklearn import svm
import numpy as np
from sklearn.ensemble import IsolationForest
import pandas as pd
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import warnings

# %%
data = pd.read_csv('C:/Users/User/Desktop/ФГУП НТЦ РХБГ 2022/Другое/Data Science 2022/HW/Python/ML/HW8/train.csv', usecols=['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km', 'price_doc'])

col = ['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km']

data.head()
# Out:
#    full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0       43     27.0    4.0        NaN       NaN         NaN       NaN
# 1       34     19.0    3.0        NaN       NaN         NaN       NaN
# 2       43     29.0    2.0        NaN       NaN         NaN       NaN
# 3       89     50.0    9.0        NaN       NaN         NaN       NaN
# 4       77     77.0    4.0        NaN       NaN         NaN       NaN
#
#    kitch_sq  state        area_m  ...     ts_km  big_market_km  \
# 0       NaN    NaN  6.407578e+06  ...  4.308127      10.814172
# 1       NaN    NaN  9.589337e+06  ...  0.725560       6.910568
# 2       NaN    NaN  4.808270e+06  ...  3.562188       5.752368
# 3       NaN    NaN  1.258354e+07  ...  0.583025      27.892717
# 4       NaN    NaN  8.398461e+06  ...  2.609420       9.155057
#
#    market_shop_km  fitness_km  university_km  workplaces_km  \
# 0        1.676258    0.485841       6.715026       0.884350
# 1        3.424716    0.668364       1.852560       0.686252
# 2        1.375443    0.733101       0.841254       1.510089
# 3        0.811275    0.623484      10.903161       0.622272
# 4        1.969738    0.220288       0.991683       0.892668
#
#    shopping_centers_km  office_km  preschool_km  price_doc
# 0             0.648488   0.637189      0.177975    5850000
# 1             0.519311   0.688796      0.273345    6000000
# 2             1.486533   1.543049      0.158072    5700000
# 3             0.599914   0.934273      0.236455   13100000
# 4             0.429052   0.077901      0.376838   16331452
#
# [5 rows x 44 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   full_sq                            30471 non-null  int64
#  1   life_sq                            24088 non-null  float64
#  2   floor                              30304 non-null  float64
#  3   max_floor                          20899 non-null  float64
#  4   material                           20899 non-null  float64
#  5   build_year                         16866 non-null  float64
#  6   num_room                           20899 non-null  float64
#  7   kitch_sq                           20899 non-null  float64
#  8   state                              16912 non-null  float64
#  9   area_m                             30471 non-null  float64
#  10  raion_popul                        30471 non-null  int64
#  11  green_zone_part                    30471 non-null  float64
#  12  indust_part                        30471 non-null  float64
#  13  preschool_education_centers_raion  30471 non-null  int64
#  14  school_education_centers_raion     30471 non-null  int64
#  15  hospital_beds_raion                16030 non-null  float64
#  16  healthcare_centers_raion           30471 non-null  int64
#  17  sport_objects_raion                30471 non-null  int64
#  18  additional_education_raion         30471 non-null  int64
#  19  shopping_centers_raion             30471 non-null  int64
#  20  office_raion                       30471 non-null  int64
#  21  ID_metro                           30471 non-null  int64
#  22  metro_min_walk                     30446 non-null  float64
#  23  kindergarten_km                    30471 non-null  float64
#  24  school_km                          30471 non-null  float64
#  25  park_km                            30471 non-null  float64
#  26  green_zone_km                      30471 non-null  float64
#  27  industrial_km                      30471 non-null  float64
#  28  water_km                           30471 non-null  float64
#  29  mkad_km                            30471 non-null  float64
#  30  ttk_km                             30471 non-null  float64
#  31  sadovoe_km                         30471 non-null  float64
#  32  bulvar_ring_km                     30471 non-null  float64
#  33  kremlin_km                         30471 non-null  float64
#  34  ts_km                              30471 non-null  float64
#  35  big_market_km                      30471 non-null  float64
#  36  market_shop_km                     30471 non-null  float64
#  37  fitness_km                         30471 non-null  float64
#  38  university_km                      30471 non-null  float64
#  39  workplaces_km                      30471 non-null  float64
#  40  shopping_centers_km                30471 non-null  float64
#  41  office_km                          30471 non-null  float64
#  42  preschool_km                       30471 non-null  float64
#  43  price_doc                          30471 non-null  int64
# dtypes: float64(33), int64(11)
# memory usage: 10.2 MB

# %% [markdown]
# Посмотрим как будет работать модель с имеющимися данными

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
score_list = []

model = LinearRegression() 

data1 = data.dropna() 
X = data1[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km']]

y = data1['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5086735203503252

# %% [markdown]
# Попробуем убрать выбросы. Заменим выбросы на среднюю.

# %%
columns = ['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km', 'price_doc']

    
data2 = data.copy()

for co in columns:
    x1 = data2[co].quantile(0.25) - 5*(data2[co].quantile(0.75)) 
    x2 = data2[co].quantile(0.75) + 5*(data2[co].quantile(0.75))
    #data2.loc[((data2[co] > x1) & (data2[co] < x2 )), co] = data2[co]
    data2.loc[data2[co] < x1, co] = round(data2[co].mean())
    data2.loc[data2[co] > x2, co] = round(data2[co].mean())
    #data2.loc[data2[co] < 0, co] = round(data2[co].mean())
    
data2.head()
# Out:
#    full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0       43     27.0    4.0        NaN       NaN         NaN       NaN
# 1       34     19.0    3.0        NaN       NaN         NaN       NaN
# 2       43     29.0    2.0        NaN       NaN         NaN       NaN
# 3       89     50.0    9.0        NaN       NaN         NaN       NaN
# 4       77     77.0    4.0        NaN       NaN         NaN       NaN
#
#    kitch_sq  state        area_m  ...     ts_km  big_market_km  \
# 0       NaN    NaN  6.407578e+06  ...  4.308127      10.814172
# 1       NaN    NaN  9.589337e+06  ...  0.725560       6.910568
# 2       NaN    NaN  4.808270e+06  ...  3.562188       5.752368
# 3       NaN    NaN  1.258354e+07  ...  0.583025      27.892717
# 4       NaN    NaN  8.398461e+06  ...  2.609420       9.155057
#
#    market_shop_km  fitness_km  university_km  workplaces_km  \
# 0        1.676258    0.485841       6.715026       0.884350
# 1        3.424716    0.668364       1.852560       0.686252
# 2        1.375443    0.733101       0.841254       1.510089
# 3        0.811275    0.623484      10.903161       0.622272
# 4        1.969738    0.220288       0.991683       0.892668
#
#    shopping_centers_km  office_km  preschool_km  price_doc
# 0             0.648488   0.637189      0.177975    5850000
# 1             0.519311   0.688796      0.273345    6000000
# 2             1.486533   1.543049      0.158072    5700000
# 3             0.599914   0.934273      0.236455   13100000
# 4             0.429052   0.077901      0.376838   16331452
#
# [5 rows x 44 columns]

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   full_sq                            30471 non-null  int64
#  1   life_sq                            24088 non-null  float64
#  2   floor                              30304 non-null  float64
#  3   max_floor                          20899 non-null  float64
#  4   material                           20899 non-null  float64
#  5   build_year                         16866 non-null  float64
#  6   num_room                           20899 non-null  float64
#  7   kitch_sq                           20899 non-null  float64
#  8   state                              16912 non-null  float64
#  9   area_m                             30471 non-null  float64
#  10  raion_popul                        30471 non-null  int64
#  11  green_zone_part                    30471 non-null  float64
#  12  indust_part                        30471 non-null  float64
#  13  preschool_education_centers_raion  30471 non-null  int64
#  14  school_education_centers_raion     30471 non-null  int64
#  15  hospital_beds_raion                16030 non-null  float64
#  16  healthcare_centers_raion           30471 non-null  int64
#  17  sport_objects_raion                30471 non-null  int64
#  18  additional_education_raion         30471 non-null  int64
#  19  shopping_centers_raion             30471 non-null  int64
#  20  office_raion                       30471 non-null  int64
#  21  ID_metro                           30471 non-null  int64
#  22  metro_min_walk                     30446 non-null  float64
#  23  kindergarten_km                    30471 non-null  float64
#  24  school_km                          30471 non-null  float64
#  25  park_km                            30471 non-null  float64
#  26  green_zone_km                      30471 non-null  float64
#  27  industrial_km                      30471 non-null  float64
#  28  water_km                           30471 non-null  float64
#  29  mkad_km                            30471 non-null  float64
#  30  ttk_km                             30471 non-null  float64
#  31  sadovoe_km                         30471 non-null  float64
#  32  bulvar_ring_km                     30471 non-null  float64
#  33  kremlin_km                         30471 non-null  float64
#  34  ts_km                              30471 non-null  float64
#  35  big_market_km                      30471 non-null  float64
#  36  market_shop_km                     30471 non-null  float64
#  37  fitness_km                         30471 non-null  float64
#  38  university_km                      30471 non-null  float64
#  39  workplaces_km                      30471 non-null  float64
#  40  shopping_centers_km                30471 non-null  float64
#  41  office_km                          30471 non-null  float64
#  42  preschool_km                       30471 non-null  float64
#  43  price_doc                          30471 non-null  int64
# dtypes: float64(33), int64(11)
# memory usage: 10.2 MB

# %%
data3 = data2.dropna() 
X = data3[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km']]

y = data3['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.528428977759031

# %% [markdown]
# Стало немного лучше. Попробуем убрать NaN

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from tqdm.notebook import trange, tqdm

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30471 entries, 0 to 30470
# Data columns (total 44 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   full_sq                            30471 non-null  int64
#  1   life_sq                            24088 non-null  float64
#  2   floor                              30304 non-null  float64
#  3   max_floor                          20899 non-null  float64
#  4   material                           20899 non-null  float64
#  5   build_year                         16866 non-null  float64
#  6   num_room                           20899 non-null  float64
#  7   kitch_sq                           20899 non-null  float64
#  8   state                              16912 non-null  float64
#  9   area_m                             30471 non-null  float64
#  10  raion_popul                        30471 non-null  int64
#  11  green_zone_part                    30471 non-null  float64
#  12  indust_part                        30471 non-null  float64
#  13  preschool_education_centers_raion  30471 non-null  int64
#  14  school_education_centers_raion     30471 non-null  int64
#  15  hospital_beds_raion                16030 non-null  float64
#  16  healthcare_centers_raion           30471 non-null  int64
#  17  sport_objects_raion                30471 non-null  int64
#  18  additional_education_raion         30471 non-null  int64
#  19  shopping_centers_raion             30471 non-null  int64
#  20  office_raion                       30471 non-null  int64
#  21  ID_metro                           30471 non-null  int64
#  22  metro_min_walk                     30446 non-null  float64
#  23  kindergarten_km                    30471 non-null  float64
#  24  school_km                          30471 non-null  float64
#  25  park_km                            30471 non-null  float64
#  26  green_zone_km                      30471 non-null  float64
#  27  industrial_km                      30471 non-null  float64
#  28  water_km                           30471 non-null  float64
#  29  mkad_km                            30471 non-null  float64
#  30  ttk_km                             30471 non-null  float64
#  31  sadovoe_km                         30471 non-null  float64
#  32  bulvar_ring_km                     30471 non-null  float64
#  33  kremlin_km                         30471 non-null  float64
#  34  ts_km                              30471 non-null  float64
#  35  big_market_km                      30471 non-null  float64
#  36  market_shop_km                     30471 non-null  float64
#  37  fitness_km                         30471 non-null  float64
#  38  university_km                      30471 non-null  float64
#  39  workplaces_km                      30471 non-null  float64
#  40  shopping_centers_km                30471 non-null  float64
#  41  office_km                          30471 non-null  float64
#  42  preschool_km                       30471 non-null  float64
#  43  price_doc                          30471 non-null  int64
# dtypes: float64(33), int64(11)
# memory usage: 10.2 MB

# %%
pr = ['life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 
'kitch_sq', 'state', 'hospital_beds_raion', 'metro_min_walk']
cols = ['full_sq', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km', 'price_doc']
data4 = data2.copy()
ind = data4[data4[pr].isna()].index
data4 = data4.fillna(data4[pr].mean())


for i in trange(10):
    rf = RandomForestRegressor(max_depth=5).fit(data4[cols], data4[pr])
    data4.loc[ind, pr] = rf.predict(data4.loc[ind, cols])
    
    
data4.head()
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=10.0), HTML(value='')))
#    full_sq    life_sq     floor  max_floor  material   build_year  num_room  \
# 0       43  31.342237  7.195917  12.343018  1.837383  1917.173372  1.906401
# 1       34  31.357906  7.199735  12.347649  1.838641  1917.096745  1.906318
# 2       43  31.357906  7.199735  12.347649  1.838641  1917.096745  1.906318
# 3       89  34.332479  8.338819  13.226334  1.720555  1909.066466  1.965366
# 4       77  33.399615  6.202653  11.121120  2.091425  1936.052687  2.017070
#
#    kitch_sq     state        area_m  ...     ts_km  big_market_km  \
# 0  6.433234  2.228866  6.407578e+06  ...  4.308127      10.814172
# 1  6.432355  2.228057  9.589337e+06  ...  0.725560       6.910568
# 2  6.432355  2.228057  4.808270e+06  ...  3.562188       5.752368
# 3  6.579066  2.190482  1.258354e+07  ...  0.583025      27.892717
# 4  6.691454  2.276908  8.398461e+06  ...  2.609420       9.155057
#
#    market_shop_km  fitness_km  university_km  workplaces_km  \
# 0        1.676258    0.485841       6.715026       0.884350
# 1        3.424716    0.668364       1.852560       0.686252
# 2        1.375443    0.733101       0.841254       1.510089
# 3        0.811275    0.623484      10.903161       0.622272
# 4        1.969738    0.220288       0.991683       0.892668
#
#    shopping_centers_km  office_km  preschool_km  price_doc
# 0             0.648488   0.637189      0.177975    5850000
# 1             0.519311   0.688796      0.273345    6000000
# 2             1.486533   1.543049      0.158072    5700000
# 3             0.599914   0.934273      0.236455   13100000
# 4             0.429052   0.077901      0.376838   16331452
#
# [5 rows x 44 columns]

# %%
X = data4[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km']]

y = data4['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5291272792193427

# %%
data4.head()
# Out:
#    full_sq    life_sq     floor  max_floor  material   build_year  num_room  \
# 0       43  31.342237  7.195917  12.343018  1.837383  1917.173372  1.906401
# 1       34  31.357906  7.199735  12.347649  1.838641  1917.096745  1.906318
# 2       43  31.357906  7.199735  12.347649  1.838641  1917.096745  1.906318
# 3       89  34.332479  8.338819  13.226334  1.720555  1909.066466  1.965366
# 4       77  33.399615  6.202653  11.121120  2.091425  1936.052687  2.017070
#
#    kitch_sq     state        area_m  ...     ts_km  big_market_km  \
# 0  6.433234  2.228866  6.407578e+06  ...  4.308127      10.814172
# 1  6.432355  2.228057  9.589337e+06  ...  0.725560       6.910568
# 2  6.432355  2.228057  4.808270e+06  ...  3.562188       5.752368
# 3  6.579066  2.190482  1.258354e+07  ...  0.583025      27.892717
# 4  6.691454  2.276908  8.398461e+06  ...  2.609420       9.155057
#
#    market_shop_km  fitness_km  university_km  workplaces_km  \
# 0        1.676258    0.485841       6.715026       0.884350
# 1        3.424716    0.668364       1.852560       0.686252
# 2        1.375443    0.733101       0.841254       1.510089
# 3        0.811275    0.623484      10.903161       0.622272
# 4        1.969738    0.220288       0.991683       0.892668
#
#    shopping_centers_km  office_km  preschool_km  price_doc
# 0             0.648488   0.637189      0.177975    5850000
# 1             0.519311   0.688796      0.273345    6000000
# 2             1.486533   1.543049      0.158072    5700000
# 3             0.599914   0.934273      0.236455   13100000
# 4             0.429052   0.077901      0.376838   16331452
#
# [5 rows x 44 columns]

# %% [markdown]
# Внесенные значения скорее всего должны быть круглыми. Сделаем их таковыми.

# %%
pr = ['life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 
'kitch_sq', 'state', 'hospital_beds_raion', 'metro_min_walk']

data5 = data4.copy()
for p in pr:
    data5.loc[data5[p]%1 !=0, p] = round(data5[p])

# %%
data5.head()
# Out:
#    full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 1       34     31.0    7.0       12.0       2.0      1917.0       2.0
# 2       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 3       89     34.0    8.0       13.0       2.0      1909.0       2.0
# 4       77     33.0    6.0       11.0       2.0      1936.0       2.0
#
#    kitch_sq  state        area_m  ...     ts_km  big_market_km  \
# 0       6.0    2.0  6.407578e+06  ...  4.308127      10.814172
# 1       6.0    2.0  9.589337e+06  ...  0.725560       6.910568
# 2       6.0    2.0  4.808270e+06  ...  3.562188       5.752368
# 3       7.0    2.0  1.258354e+07  ...  0.583025      27.892717
# 4       7.0    2.0  8.398461e+06  ...  2.609420       9.155057
#
#    market_shop_km  fitness_km  university_km  workplaces_km  \
# 0        1.676258    0.485841       6.715026       0.884350
# 1        3.424716    0.668364       1.852560       0.686252
# 2        1.375443    0.733101       0.841254       1.510089
# 3        0.811275    0.623484      10.903161       0.622272
# 4        1.969738    0.220288       0.991683       0.892668
#
#    shopping_centers_km  office_km  preschool_km  price_doc
# 0             0.648488   0.637189      0.177975    5850000
# 1             0.519311   0.688796      0.273345    6000000
# 2             1.486533   1.543049      0.158072    5700000
# 3             0.599914   0.934273      0.236455   13100000
# 4             0.429052   0.077901      0.376838   16331452
#
# [5 rows x 44 columns]

# %%
X = data5[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'additional_education_raion', 'preschool_km']]

y = data5['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5291076632864609

# %% [markdown]
# Добавим 5 новых полей:
#
# Отношение жилой площади к общей \
# Отношение этажа квартиры к количеству этаже в доме \
# Общее количество коек в медицинских центрах в районе квартиры \
# Отношение состояния квартиры к году строительства дома \
# Преобразуем в полиномиальную модель со степенью 2

# %% [markdown]
# Так как все данные числовые, то энкодинг делать не на чем. Попробуем объединить схожие данные в кластеры, а также придумать какие-нибудь новые признаки.

# %% [markdown]
# Попробуем кластеризовать по району

# %%
data6 = data5.copy()
kmeans = KMeans(n_clusters=5) 
cluster = kmeans.fit_predict(data5[['mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km']])
data6['district'] = cluster
data6.head()
# Out:
#    full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 1       34     31.0    7.0       12.0       2.0      1917.0       2.0
# 2       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 3       89     34.0    8.0       13.0       2.0      1909.0       2.0
# 4       77     33.0    6.0       11.0       2.0      1936.0       2.0
#
#    kitch_sq  state        area_m  ...  big_market_km  market_shop_km  \
# 0       6.0    2.0  6.407578e+06  ...      10.814172        1.676258
# 1       6.0    2.0  9.589337e+06  ...       6.910568        3.424716
# 2       6.0    2.0  4.808270e+06  ...       5.752368        1.375443
# 3       7.0    2.0  1.258354e+07  ...      27.892717        0.811275
# 4       7.0    2.0  8.398461e+06  ...       9.155057        1.969738
#
#    fitness_km  university_km  workplaces_km  shopping_centers_km  office_km  \
# 0    0.485841       6.715026       0.884350             0.648488   0.637189
# 1    0.668364       1.852560       0.686252             0.519311   0.688796
# 2    0.733101       0.841254       1.510089             1.486533   1.543049
# 3    0.623484      10.903161       0.622272             0.599914   0.934273
# 4    0.220288       0.991683       0.892668             0.429052   0.077901
#
#    preschool_km  price_doc  district
# 0      0.177975    5850000         3
# 1      0.273345    6000000         1
# 2      0.158072    5700000         1
# 3      0.236455   13100000         0
# 4      0.376838   16331452         1
#
# [5 rows x 45 columns]

# %%
X = data6[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'preschool_km', 'district']]

y = data6['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5290904042838105

# %% [markdown]
# Кластеризуем по доступности образования

# %%
data7 = data6.copy()
kmeans = KMeans(n_clusters=5) 
cluster = kmeans.fit_predict(data5[['preschool_education_centers_raion', 'school_education_centers_raion', 
'additional_education_raion', 'kindergarten_km','school_km', 'university_km', 'preschool_km']])
data7['education'] = cluster
data7.head()
# Out:
#    full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 1       34     31.0    7.0       12.0       2.0      1917.0       2.0
# 2       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 3       89     34.0    8.0       13.0       2.0      1909.0       2.0
# 4       77     33.0    6.0       11.0       2.0      1936.0       2.0
#
#    kitch_sq  state        area_m  ...  market_shop_km  fitness_km  \
# 0       6.0    2.0  6.407578e+06  ...        1.676258    0.485841
# 1       6.0    2.0  9.589337e+06  ...        3.424716    0.668364
# 2       6.0    2.0  4.808270e+06  ...        1.375443    0.733101
# 3       7.0    2.0  1.258354e+07  ...        0.811275    0.623484
# 4       7.0    2.0  8.398461e+06  ...        1.969738    0.220288
#
#    university_km  workplaces_km  shopping_centers_km  office_km  preschool_km  \
# 0       6.715026       0.884350             0.648488   0.637189      0.177975
# 1       1.852560       0.686252             0.519311   0.688796      0.273345
# 2       0.841254       1.510089             1.486533   1.543049      0.158072
# 3      10.903161       0.622272             0.599914   0.934273      0.236455
# 4       0.991683       0.892668             0.429052   0.077901      0.376838
#
#    price_doc  district  education
# 0    5850000         3          0
# 1    6000000         1          2
# 2    5700000         1          2
# 3   13100000         0          0
# 4   16331452         1          2
#
# [5 rows x 46 columns]

# %%
X = data7[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'preschool_km', 'district', 'education']]

y = data7['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5303440082618915

# %% [markdown]
# Кластеризуем по социальной инфраструктуре

# %%
data8 = data7.copy()
kmeans = KMeans(n_clusters=5) 
cluster = kmeans.fit_predict(data5[['green_zone_part', 'hospital_beds_raion', 'healthcare_centers_raion',
'sport_objects_raion', 'shopping_centers_raion','metro_min_walk']])
data8['social'] = cluster
data8.head()
# Out:
#    full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 1       34     31.0    7.0       12.0       2.0      1917.0       2.0
# 2       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 3       89     34.0    8.0       13.0       2.0      1909.0       2.0
# 4       77     33.0    6.0       11.0       2.0      1936.0       2.0
#
#    kitch_sq  state        area_m  ...  fitness_km  university_km  \
# 0       6.0    2.0  6.407578e+06  ...    0.485841       6.715026
# 1       6.0    2.0  9.589337e+06  ...    0.668364       1.852560
# 2       6.0    2.0  4.808270e+06  ...    0.733101       0.841254
# 3       7.0    2.0  1.258354e+07  ...    0.623484      10.903161
# 4       7.0    2.0  8.398461e+06  ...    0.220288       0.991683
#
#    workplaces_km  shopping_centers_km  office_km  preschool_km  price_doc  \
# 0       0.884350             0.648488   0.637189      0.177975    5850000
# 1       0.686252             0.519311   0.688796      0.273345    6000000
# 2       1.510089             1.486533   1.543049      0.158072    5700000
# 3       0.622272             0.599914   0.934273      0.236455   13100000
# 4       0.892668             0.429052   0.077901      0.376838   16331452
#
#    district  education  social
# 0         3          0       3
# 1         1          2       3
# 2         1          2       3
# 3         0          0       3
# 4         1          2       2
#
# [5 rows x 47 columns]

# %%
X = data8[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'preschool_km', 'district', 'education', 'social']]

y = data8['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5307811783004379

# %% [markdown]
# Вставим признаки отношения площади жилой к общей и площади кухни к общей.

# %%
data9 = data8.copy()
data9['fl_sq'] = round((data9['life_sq'] / data9['full_sq']), 5)
data9['fk_sq'] = round((data9['kitch_sq'] / data9['full_sq']), 5)
data9.head()
# Out:
#    full_sq  life_sq  floor  max_floor  material  build_year  num_room  \
# 0       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 1       34     31.0    7.0       12.0       2.0      1917.0       2.0
# 2       43     31.0    7.0       12.0       2.0      1917.0       2.0
# 3       89     34.0    8.0       13.0       2.0      1909.0       2.0
# 4       77     33.0    6.0       11.0       2.0      1936.0       2.0
#
#    kitch_sq  state        area_m  ...  workplaces_km  shopping_centers_km  \
# 0       6.0    2.0  6.407578e+06  ...       0.884350             0.648488
# 1       6.0    2.0  9.589337e+06  ...       0.686252             0.519311
# 2       6.0    2.0  4.808270e+06  ...       1.510089             1.486533
# 3       7.0    2.0  1.258354e+07  ...       0.622272             0.599914
# 4       7.0    2.0  8.398461e+06  ...       0.892668             0.429052
#
#    office_km  preschool_km  price_doc  district  education  social    fl_sq  \
# 0   0.637189      0.177975    5850000         3          0       3  0.72093
# 1   0.688796      0.273345    6000000         1          2       3  0.91176
# 2   1.543049      0.158072    5700000         1          2       3  0.72093
# 3   0.934273      0.236455   13100000         0          0       3  0.38202
# 4   0.077901      0.376838   16331452         1          2       2  0.42857
#
#      fk_sq
# 0  0.13953
# 1  0.17647
# 2  0.13953
# 3  0.07865
# 4  0.09091
#
# [5 rows x 49 columns]

# %%
X = data9[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'preschool_km', 'district', 'education', 'social']]

y = data9['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5307811783004379

# %% [markdown]
# Попробуем преобразовать в полиноминальную модель

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=2)

X = data9[['full_sq', 'life_sq', 'floor', 'max_floor', 'material', 'build_year', 'num_room', 'kitch_sq',
'state', 'area_m', 'raion_popul', 'green_zone_part', 'indust_part', 'preschool_education_centers_raion',
'school_education_centers_raion', 'hospital_beds_raion', 'healthcare_centers_raion', 'sport_objects_raion',
'additional_education_raion', 'shopping_centers_raion', 'office_raion', 'ID_metro', 'metro_min_walk', 'kindergarten_km',
'school_km', 'park_km', 'green_zone_km', 'industrial_km', 'water_km', 'mkad_km', 'ttk_km', 'sadovoe_km', 'bulvar_ring_km',
'kremlin_km', 'ts_km', 'big_market_km','market_shop_km', 'fitness_km', 'university_km', 'workplaces_km', 'shopping_centers_km',
'office_km', 'preschool_km', 'district', 'education', 'social']]

X_poly = poly_reg.fit_transform(X)

y = data9['price_doc']

X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.25, random_state=42)

model.fit(X_train, y_train)

score = model.score(X_test, y_test)

score_list.append(score)

score
# Out:
# 0.5881664230449851

# %% [markdown]
# Сильно улучшить модель от изначальной не вышло.

# %%
plt.plot([i for i in range(0, len(score_list))], score_list)
